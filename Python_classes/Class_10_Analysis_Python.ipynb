# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd
import numpy as np

# %%
#dir = r"/Users/admin/Documents/workspace/venv/New_Python_Classes/OnlineOrders_of_a_ecommerce_website.csv"
dir= r'\Users\Josey\Documents\pythonprojects\project1\OnlineOrders_of_a_ecommerce_website.csv'
df = pd.read_csv(dir)
df
# Out:
#                 crawl_timestamp  \
# 0     2016-03-25 22:59:23+00:00
# 1     2016-03-25 22:59:23+00:00
# 2     2016-03-25 22:59:23+00:00
# 3     2016-03-25 22:59:23+00:00
# 4     2016-03-25 22:59:23+00:00
# ...                         ...
# 8078  2016-03-05 12:31:04+00:00
# 8079  2016-03-05 12:31:04+00:00
# 8080  2016-03-05 12:31:04+00:00
# 8081  2016-03-05 12:31:04+00:00
# 8082  2016-03-05 12:31:04+00:00
#
#                                            product_name  \
# 0                   Alisha Solid Women's Cycling Shorts
# 1                   FabHomeDecor Fabric Double Sofa Bed
# 2                                            AW Bellies
# 3                   Alisha Solid Women's Cycling Shorts
# 4                 Sicons All Purpose Arnica Dog Shampoo
# ...                                                 ...
# 8078  Sinina Chanderi Embroidered Salwar Suit Dupatt...
# 8079  Aarushi Fashion Chanderi Embroidered Salwar Su...
# 8080  Ambika Lahenga Embroidered Lehenga, Choli and ...
# ...

# %%
count_brand = len(df["brand"].unique())
count_brand
# Out:
# 2587

# %%
len(str(count_brand))
# Out:
# 4

# %%
2587
# 0001
# 0023
# 0457
# Out:
# 2587

# %%
unique_info = []
for i in range(1, count_brand+1):
    if len(str(i)) == 1:
        x1 = f"000{i}"
        unique_info.append(x1)
    elif len(str(i)) == 2:
        x2 = f"00{i}"
        unique_info.append(x2)
    elif len(str(i)) == 3:
        x3 = f"0{i}"
        unique_info.append(x3)
    else:
        unique_info.append(i)


len(unique_info)
# Out:
# 2587

# %%
# unique_id = [int(i) for i in unique_info]
#unique_id
# Out:
# 2586

# %%
unique_brand = df["brand"].unique()
unique_brand
# Out:
# array(['Alisha', 'FabHomeDecor', 'AW', ..., 'Sinina', 'Aarushi Fashion',
#        'Ambika Lahenga'], dtype=object)

# %%
len(unique_brand)
# Out:
# 2587

# %%
map_brand_id = dict(zip(unique_brand,unique_info))
map_brand_id
# Out:
# {'Alisha': '0001',
#  'FabHomeDecor': '0002',
#  'AW': '0003',
#  'Sicons': '0004',
#  'Eternal Gandhi': '0005',
#  'dilli bazaaar': '0006',
#  'Ladela': '0007',
#  'Carrel': '0008',
#  'Freelance': '0009',
#  'Style Foot': '0010',
#  'dongli': '0011',
#  'SWAGGA': '0012',
#  'Kennel': '0013',
#  'Madcaps': '0014',
#  'Bengal Blooms': '0015',
#  'Indcrown': '0016',
#  'Shopmania': '0017',
#  'Tiara Diaries': '0018',
#  'KAJCI': '0019',
#  'Packman': '0020',
#  'Pick Pocket': '0021',
#  'Angelfish': '0022',
#  'Oye': '0023',
#  'Nuride': '0024',
#  'OM SHIVAKRITI': '0025',
#  'Himmlisch': '0026',
#  'Rapter': '0027',
#  'Vishudh': '0028',
#  'BuildTrack': '0029',
#  'Skayvon': '0030',
#  'MASARA': '0031',
#  'Behringer': '0032',
#  'Roadster': '0033',
#  'Noor': '0034',
#  'Libas': '0035',
#  'HRS': '0036',
#  'Vermello': '0037',
#  'Ligans NY': '0038',
#  'Elegance': '0039',
#  'Liza': '0040',
#  'Sathiyas': '0041',
#  'SANTOSH ROYAL FASHION': '0042',
#  'CASEDEAL': '0043',
# ...

# %%
# df["id"] = df["brand"].apply(map_brand_id)
# df

df["id"] = df["brand"].map(map_brand_id).fillna('Unknown')
df["id"]
# Out:
# 0       0001
# 1       0002
# 2       0003
# 3       0001
# 4       0004
#         ...
# 8078    2585
# 8079    2586
# 8080    2587
# 8081    2585
# 8082    2586
# Name: id, Length: 8083, dtype: object

# %%
df
# Out:
#                 crawl_timestamp  \
# 0     2016-03-25 22:59:23+00:00
# 1     2016-03-25 22:59:23+00:00
# 2     2016-03-25 22:59:23+00:00
# 3     2016-03-25 22:59:23+00:00
# 4     2016-03-25 22:59:23+00:00
# ...                         ...
# 8078  2016-03-05 12:31:04+00:00
# 8079  2016-03-05 12:31:04+00:00
# 8080  2016-03-05 12:31:04+00:00
# 8081  2016-03-05 12:31:04+00:00
# 8082  2016-03-05 12:31:04+00:00
#
#                                            product_name  \
# 0                   Alisha Solid Women's Cycling Shorts
# 1                   FabHomeDecor Fabric Double Sofa Bed
# 2                                            AW Bellies
# 3                   Alisha Solid Women's Cycling Shorts
# 4                 Sicons All Purpose Arnica Dog Shampoo
# ...                                                 ...
# 8078  Sinina Chanderi Embroidered Salwar Suit Dupatt...
# 8079  Aarushi Fashion Chanderi Embroidered Salwar Su...
# 8080  Ambika Lahenga Embroidered Lehenga, Choli and ...
# ...

# %%
# df[df["id"] == "Unknown"]

# %%
id_df = df[["brand", "id"]]
id_df
# Out:
#                 brand    id
# 0              Alisha  0001
# 1        FabHomeDecor  0002
# 2                  AW  0003
# 3              Alisha  0001
# 4              Sicons  0004
# ...               ...   ...
# 8078           Sinina  2585
# 8079  Aarushi Fashion  2586
# 8080   Ambika Lahenga  2587
# 8081           Sinina  2585
# 8082  Aarushi Fashion  2586
#
# [8083 rows x 2 columns]

# %%
## Start ######

# %%
df.shape
# Out:
# (8083, 7)

# %%
df.columns
# Out:
# Index(['crawl_timestamp', 'product_name', 'product_category_tree',
#        'retail_price', 'discounted_price', 'brand', 'id'],
#       dtype='object')

# %%
# This is to check for datatype information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8083 entries, 0 to 8082
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   crawl_timestamp        8083 non-null   object
#  1   product_name           8083 non-null   object
#  2   product_category_tree  8083 non-null   object
#  3   retail_price           8083 non-null   float64
#  4   discounted_price       8083 non-null   float64
#  5   brand                  8083 non-null   object
#  6   id                     8083 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 442.2+ KB

# %%
# Check for missing values
df.isna().sum()
# Out:
# crawl_timestamp          0
# product_name             0
# product_category_tree    0
# retail_price             0
# discounted_price         0
# brand                    0
# id                       0
# dtype: int64

# %%
## get counts of distinct brands b
len(df["brand"].unique())
# Out:
# 2587

# %%
# count all brands 
df["brand"].value_counts()
# Out:
# brand
# Karatcraft              211
# Black                   164
# White                   155
# DailyObjects            144
# Radiant Bay             132
#                        ...
# Tks                       1
# urban monk creations      1
# narayan export            1
# Right                     1
# Ambika Lahenga            1
# Name: count, Length: 2587, dtype: int64

# %%
### Brand Coounts ######

brand_counts_df = df["brand"].value_counts().reset_index()
brand_counts_df
# Out:
#                      brand  count
# 0               Karatcraft    211
# 1                    Black    164
# 2                    White    155
# 3             DailyObjects    144
# 4              Radiant Bay    132
# ...                    ...    ...
# 2582                   Tks      1
# 2583  urban monk creations      1
# 2584        narayan export      1
# 2585                 Right      1
# 2586        Ambika Lahenga      1
#
# [2587 rows x 2 columns]

# %%
brand_counts_df_df = pd.merge(brand_counts_df, id_df, on="brand")
brand_counts_df_df
# Out:
#                      brand  count    id
# 0               Karatcraft    211  0092
# 1               Karatcraft    211  0092
# 2               Karatcraft    211  0092
# 3               Karatcraft    211  0092
# 4               Karatcraft    211  0092
# ...                    ...    ...   ...
# 8078                   Tks      1  1125
# 8079  urban monk creations      1  1123
# 8080        narayan export      1  1122
# 8081                 Right      1  1121
# 8082        Ambika Lahenga      1  2587
#
# [8083 rows x 3 columns]

# %%
brand_counts_df_df = brand_counts_df_df.drop_duplicates()
brand_counts_df_df
# Out:
#                      brand  count    id
# 0               Karatcraft    211  0092
# 211                  Black    164  0452
# 375                  White    155  0558
# 530           DailyObjects    144  0105
# 674            Radiant Bay    132  0480
# ...                    ...    ...   ...
# 8078                   Tks      1  1125
# 8079  urban monk creations      1  1123
# 8080        narayan export      1  1122
# 8081                 Right      1  1121
# 8082        Ambika Lahenga      1  2587
#
# [2587 rows x 3 columns]

# %%
brand_counts_df_df["brand"] = brand_counts_df_df["brand"].str.lower()
# Out:
# C:\Users\Josey\AppData\Local\Temp\ipykernel_41508\2659167508.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   brand_counts_df_df["brand"] = brand_counts_df_df["brand"].str.lower()

# %%
brand_counts_df_df
# Out:
#                      brand  count    id
# 0               karatcraft    211  0092
# 211                  black    164  0452
# 375                  white    155  0558
# 530           dailyobjects    144  0105
# 674            radiant bay    132  0480
# ...                    ...    ...   ...
# 8078                   tks      1  1125
# 8079  urban monk creations      1  1123
# 8080        narayan export      1  1122
# 8081                 right      1  1121
# 8082        ambika lahenga      1  2587
#
# [2587 rows x 3 columns]

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
\Users\Josey\Documents\pythonprojects\project1\

# %%
#brand_counts_df_df.to_csv("brand_counts_TB.csv", index=False)

# %%
brand_counts_df_df.to_csv(r"\Users\Josey\Documents\pythonprojects\project1\brand_counts_TB.csv", index=False)

# %%
brand_counts_df_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2587 entries, 0 to 8082
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   brand   2587 non-null   object
#  1   count   2587 non-null   int64
#  2   id      2587 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 80.8+ KB

# %%
brand_counts_df[brand_counts_df["brand"] == "Alisha"]
# Out:
#       brand  count
# 222  Alisha      6

# %%
# A More manual Approach
data_dict = {}

brand_arr = list(df["brand"].values)
for i in brand_arr:
    data_dict[i] = brand_arr.count(i)

count_df = pd.DataFrame([data_dict])
count_df = count_df.T
count_df = count_df.reset_index()
count_df.columns = ["names", "counts"]
count_df.sort_values(by="counts", ascending=False)
# Out:
#                      names  counts
# 91              Karatcraft     211
# 451                  Black     164
# 557                  White     155
# 104           DailyObjects     144
# 479            Radiant Bay     132
# ...                    ...     ...
# 1124                   Tks       1
# 1122  urban monk creations       1
# 1121        narayan export       1
# 1120                 Right       1
# 2586        Ambika Lahenga       1
#
# [2587 rows x 2 columns]

# %%
# How Transform data
""" 
- Handle product category tree column
- Handle stamptime column
"""
# Out:
# ' \n- Handle product category tree column\n- Handle stamptime column\n'

# %%
df.columns

type(df['product_category_tree'].values[0])
# Out:
# str

# %%
df['product_category_tree'].values[0]
# Out:
# '["Clothing >> Women\'s Clothing >> Lingerie, Sleep & Swimwear >> Shorts >> Alisha Shorts >> Alisha Solid Women\'s Cycling Shorts"]'

# %%
len(df['product_category_tree'].values[0])
# Out:
# 128

# %%
# for i in df['product_category_tree'].values[0]:
#     print(i)

# %%
a = "abc-dc"

# %%
# lst_data = eval(df['product_category_tree'].values[0])
# for i in lst_data:
#     print(i.split(">>"))

# %%
# lst_data = eval(df['product_category_tree'].values[0])
# for i in lst_data:
#     data = i.split(">>")
#     for i in data:
#         print(i)

# %%
df.shape[0]
# Out:
# 8083

# %%
df.columns
# Out:
# Index(['crawl_timestamp', 'product_name', 'product_category_tree',
#        'retail_price', 'discounted_price', 'brand', 'id'],
#       dtype='object')

# %%
data_arr = []
id_data = []
for n in range(0, df.shape[0]):
    lst_data = eval(df['product_category_tree'].values[n])
    unique_id = df["id"].values[n]
    id_data.append(unique_id)
    for i in lst_data:
        splitter = i.split(">>")
        data_arr.append(splitter)

# %%
df_new = pd.DataFrame(data_arr)
df_id = pd.DataFrame(id_data)
df_id.columns = ["id"]
df_new
df_new.columns = ["items", "item_class", "item_subclass", "products",
 "product_brand", "product_subbrand", "product_subclass", "product_brand_item"]

# %%
df_new
# Out:
#               items               item_class                 item_subclass  \
# 0         Clothing         Women's Clothing    Lingerie, Sleep & Swimwear
# 1        Furniture    Living Room Furniture            Sofa Beds & Futons
# 2         Footwear         Women's Footwear                    Ballerinas
# 3         Clothing         Women's Clothing    Lingerie, Sleep & Swimwear
# 4     Pet Supplies                 Grooming              Skin & Coat Care
# ...             ...                      ...                           ...
# 8078      Clothing         Women's Clothing                   Ethnic Wear
# 8079      Clothing         Women's Clothing                   Ethnic Wear
# 8080      Clothing         Women's Clothing                   Ethnic Wear
# 8081      Clothing         Women's Clothing                   Ethnic Wear
# 8082      Clothing         Women's Clothing                   Ethnic Wear
#
#                                                products  \
# ...

# %%
df_id
# Out:
#         id
# 0     0001
# 1     0002
# 2     0003
# 3     0001
# 4     0004
# ...    ...
# 8078  2585
# 8079  2586
# 8080  2587
# 8081  2585
# 8082  2586
#
# [8083 rows x 1 columns]

# %%
new_df = pd.concat([df_new, df_id], axis=1)
new_df
# Out:
#               items               item_class                 item_subclass  \
# 0         Clothing         Women's Clothing    Lingerie, Sleep & Swimwear
# 1        Furniture    Living Room Furniture            Sofa Beds & Futons
# 2         Footwear         Women's Footwear                    Ballerinas
# 3         Clothing         Women's Clothing    Lingerie, Sleep & Swimwear
# 4     Pet Supplies                 Grooming              Skin & Coat Care
# ...             ...                      ...                           ...
# 8078      Clothing         Women's Clothing                   Ethnic Wear
# 8079      Clothing         Women's Clothing                   Ethnic Wear
# 8080      Clothing         Women's Clothing                   Ethnic Wear
# 8081      Clothing         Women's Clothing                   Ethnic Wear
# 8082      Clothing         Women's Clothing                   Ethnic Wear
#
#                                                products  \
# ...

# %%
df_df_new = pd.merge(new_df, id_df, on="id")
df_df_new
# Out:
#             items          item_class                 item_subclass  \
# 0       Clothing    Women's Clothing    Lingerie, Sleep & Swimwear
# 1       Clothing    Women's Clothing    Lingerie, Sleep & Swimwear
# 2       Clothing    Women's Clothing    Lingerie, Sleep & Swimwear
# 3       Clothing    Women's Clothing    Lingerie, Sleep & Swimwear
# 4       Clothing    Women's Clothing    Lingerie, Sleep & Swimwear
# ...           ...                 ...                           ...
# 259818  Clothing    Women's Clothing                   Ethnic Wear
# 259819  Clothing    Women's Clothing                   Ethnic Wear
# 259820  Clothing    Women's Clothing                   Ethnic Wear
# 259821  Clothing    Women's Clothing                   Ethnic Wear
# 259822  Clothing    Women's Clothing                   Ethnic Wear
#
#                 products     product_brand  \
# 0                Shorts     Alisha Shorts
# 1                Shorts     Alisha Shorts
# ...

# %%
Transformed_tb = df_df_new.drop_duplicates()
Transformed_tb
# Out:
#                                                     items  \
# 0                                               Clothing
# 6                                              Furniture
# 10                                              Footwear
# 21                                          Pet Supplies
# 23      Eternal Gandhi Super Series Crystal Paper Weig...
# ...                                                   ...
# 259811  Areon Luxurious Fragrance Long Lasting Car,Hom...
# 259814                                          Clothing
# 259816                                          Clothing
# 259818                                          Clothing
# 259821                                          Clothing
#
#                      item_class                 item_subclass  \
# 0             Women's Clothing    Lingerie, Sleep & Swimwear
# 6        Living Room Furniture            Sofa Beds & Futons
# 10            Women's Footwear                    Ballerinas
# ...

# %%
# Transformed_tb.to_csv("/Users/admin/Documents/workspace/brand_categories.csv", index=False)

# %%
Transformed_tb.to_csv(r"\Users\Josey\Documents\pythonprojects\project1\brand_categories.csv", index=False)

# %%
Transformed_tb.columns
# Out:
# Index(['items', 'item_class', 'item_subclass', 'products', 'product_brand',
#        'product_subbrand', 'product_subclass', 'product_brand_item', 'id',
#        'brand'],
#       dtype='object')

# %%
df["product_category_tree"].iloc[0]
# Out:
# '["Clothing >> Women\'s Clothing >> Lingerie, Sleep & Swimwear >> Shorts >> Alisha Shorts >> Alisha Solid Women\'s Cycling Shorts"]'

# %%
#  Another Method to handle This:
# def handle_CatProd():
#         data_arr = []
#         lst_data = list(df['product_category_tree'])
#         for i in lst_data:
#                 splitter = i.split(">>")
#                 data_arr.append(splitter)

#         return data_arr


# handle_CatProd()[0][0:-1]

# %%
column_arr = []
for j in df["crawl_timestamp"].values:
    data = j.split(" ")
    column_arr.append(data)

df_time = pd.DataFrame(column_arr)
df_time.columns = ["date", "time"]

df_time
# Out:
#             date            time
# 0     2016-03-25  22:59:23+00:00
# 1     2016-03-25  22:59:23+00:00
# 2     2016-03-25  22:59:23+00:00
# 3     2016-03-25  22:59:23+00:00
# 4     2016-03-25  22:59:23+00:00
# ...          ...             ...
# 8078  2016-03-05  12:31:04+00:00
# 8079  2016-03-05  12:31:04+00:00
# 8080  2016-03-05  12:31:04+00:00
# 8081  2016-03-05  12:31:04+00:00
# 8082  2016-03-05  12:31:04+00:00
#
# [8083 rows x 2 columns]

# %%
df_time["date"] = pd.to_datetime(df_time["date"])
df_time["time"] = pd.to_datetime(df_time["time"])
#  To convert to time format it has to be in datetime already .... 
# Assuming df_time is your DataFrame and 'time_column' is the name of the column containing time values
df_time['time'] = pd.to_datetime(df_time['time'], format='%H:%M:%S').dt.time
# Out:
# C:\Users\Josey\AppData\Local\Temp\ipykernel_41508\3051620415.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_time["time"] = pd.to_datetime(df_time["time"])

# %%
df_time
# Out:
#            date      time
# 0    2016-03-25  22:59:23
# 1    2016-03-25  22:59:23
# 2    2016-03-25  22:59:23
# 3    2016-03-25  22:59:23
# 4    2016-03-25  22:59:23
# ...         ...       ...
# 8078 2016-03-05  12:31:04
# 8079 2016-03-05  12:31:04
# 8080 2016-03-05  12:31:04
# 8081 2016-03-05  12:31:04
# 8082 2016-03-05  12:31:04
#
# [8083 rows x 2 columns]

# %%
new_df_time= pd.concat([df_time, id_df], axis=1)
new_df_time.drop_duplicates
new_df_time
# Out:
#            date      time            brand    id
# 0    2016-03-25  22:59:23           Alisha  0001
# 1    2016-03-25  22:59:23     FabHomeDecor  0002
# 2    2016-03-25  22:59:23               AW  0003
# 3    2016-03-25  22:59:23           Alisha  0001
# 4    2016-03-25  22:59:23           Sicons  0004
# ...         ...       ...              ...   ...
# 8078 2016-03-05  12:31:04           Sinina  2585
# 8079 2016-03-05  12:31:04  Aarushi Fashion  2586
# 8080 2016-03-05  12:31:04   Ambika Lahenga  2587
# 8081 2016-03-05  12:31:04           Sinina  2585
# 8082 2016-03-05  12:31:04  Aarushi Fashion  2586
#
# [8083 rows x 4 columns]

# %%
new_df_time.columns
# Out:
# Index(['date', 'time', 'brand', 'id'], dtype='object')

# %%
new_df_time.to_csv(r"\Users\Josey\Documents\pythonprojects\project1\date_time.csv", index=False)

# %%
df_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8083 entries, 0 to 8082
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    8083 non-null   datetime64[ns]
#  1   time    8083 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 126.4+ KB

# %%
df
# Out:
#                 crawl_timestamp  \
# 0     2016-03-25 22:59:23+00:00
# 1     2016-03-25 22:59:23+00:00
# 2     2016-03-25 22:59:23+00:00
# 3     2016-03-25 22:59:23+00:00
# 4     2016-03-25 22:59:23+00:00
# ...                         ...
# 8078  2016-03-05 12:31:04+00:00
# 8079  2016-03-05 12:31:04+00:00
# 8080  2016-03-05 12:31:04+00:00
# 8081  2016-03-05 12:31:04+00:00
# 8082  2016-03-05 12:31:04+00:00
#
#                                            product_name  \
# 0                   Alisha Solid Women's Cycling Shorts
# 1                   FabHomeDecor Fabric Double Sofa Bed
# 2                                            AW Bellies
# 3                   Alisha Solid Women's Cycling Shorts
# 4                 Sicons All Purpose Arnica Dog Shampoo
# ...                                                 ...
# 8078  Sinina Chanderi Embroidered Salwar Suit Dupatt...
# 8079  Aarushi Fashion Chanderi Embroidered Salwar Su...
# 8080  Ambika Lahenga Embroidered Lehenga, Choli and ...
# ...

# %%
new_df = df.drop(["crawl_timestamp", "product_category_tree"], axis=1)
new_df
# Out:
#                                            product_name  retail_price  \
# 0                   Alisha Solid Women's Cycling Shorts         999.0
# 1                   FabHomeDecor Fabric Double Sofa Bed       32157.0
# 2                                            AW Bellies         999.0
# 3                   Alisha Solid Women's Cycling Shorts         699.0
# 4                 Sicons All Purpose Arnica Dog Shampoo         220.0
# ...                                                 ...           ...
# 8078  Sinina Chanderi Embroidered Salwar Suit Dupatt...        2980.0
# 8079  Aarushi Fashion Chanderi Embroidered Salwar Su...        2600.0
# 8080  Ambika Lahenga Embroidered Lehenga, Choli and ...       39992.0
# 8081  Sinina Chanderi Embroidered Salwar Suit Dupatt...        2000.0
# 8082  Aarushi Fashion Silk Striped Salwar Suit Dupat...        2800.0
#
#       discounted_price            brand    id
# 0                379.0           Alisha  0001
# ...

# %%
new_df.columns
# Out:
# Index(['product_name', 'retail_price', 'discounted_price', 'brand', 'id'], dtype='object')

# %%
new_df.to_csv(r"\Users\Josey\Documents\pythonprojects\project1\Pricing_TB.csv", index=False)

# %%
added_df = pd.concat([df_time, new_df], axis=1)
added_df
# Out:
#            date      time                                       product_name  \
# 0    2016-03-25  22:59:23                Alisha Solid Women's Cycling Shorts
# 1    2016-03-25  22:59:23                FabHomeDecor Fabric Double Sofa Bed
# 2    2016-03-25  22:59:23                                         AW Bellies
# 3    2016-03-25  22:59:23                Alisha Solid Women's Cycling Shorts
# 4    2016-03-25  22:59:23              Sicons All Purpose Arnica Dog Shampoo
# ...         ...       ...                                                ...
# 8078 2016-03-05  12:31:04  Sinina Chanderi Embroidered Salwar Suit Dupatt...
# 8079 2016-03-05  12:31:04  Aarushi Fashion Chanderi Embroidered Salwar Su...
# 8080 2016-03-05  12:31:04  Ambika Lahenga Embroidered Lehenga, Choli and ...
# 8081 2016-03-05  12:31:04  Sinina Chanderi Embroidered Salwar Suit Dupatt...
# 8082 2016-03-05  12:31:04  Aarushi Fashion Silk Striped Salwar Suit Dupat...
#
# ...

# %%
# --- addded df Table 
# --- df_new table

# %%
#---------Assignment--------------
# Everything about price and costing should be on its own table...
# Date and time table should added to the database

# %%
#For pricing and costing table we already have the dataframe so we go ahead to convert to a csv file format,which we would further upload into our database

# %%
#new_df.columns         ---------#Pricing & Cost dataframe

# %%
#new_df.to_csv(r"\Users\Josey\Documents\pythonprojects\project1\Pricing_TB.csv", index=False)

# %%
#for Date time table
#first we concatenate two tables together

# %%
#new_df_time= pd.concat([df_time, id_df], axis=1)
#new_df_time.drop_duplicates
#new_df_time

# %%
#new_df_time.columns

# %%
#new_df_time.to_csv(r"\Users\Josey\Documents\pythonprojects\project1\date_time.csv", index=False)
